# %%
import pandas as pd #alias data
import matplotlib.pyplot as plt
import seaborn as sb

# %%
data = pd.read_csv('/content/drive/MyDrive/Github/AI_DS/top50.csv', encoding="ISO-8859-1")
data.head()
plt.figure(figsize=(16,6))
sb.lineplot(data = data)
